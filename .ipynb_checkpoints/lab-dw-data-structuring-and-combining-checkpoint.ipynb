# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import numpy as np
import pandas as pd
import re

# %load_ext autoreload
# %autoreload 2 


pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 30)


car_insurance_df1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
car_insurance_df2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
car_insurance_df3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
column_list = car_insurance_df1.columns.tolist()
column_list
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
new_order2 = ['Customer',
 'ST',
 'GENDER',
 'Education',
 'Customer Lifetime Value',
 'Income',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Vehicle Class',
 'Total Claim Amount']
car_insurance_df2 = car_insurance_df2[new_order2]

# %%
new_order3 = ['Customer',
 'State',
 'Gender',
 'Education',
 'Customer Lifetime Value',
 'Income',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Vehicle Class',
 'Total Claim Amount']
car_insurance_df3 = car_insurance_df3[new_order3]

# %%
car_insurance_df1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0     0.00               1000.00                    1/0/00   Personal Auto
# 1     0.00                 94.00                    1/0/00   Personal Auto
# 2 48767.00                108.00                    1/0/00   Personal Auto
# 3     0.00                106.00                    1/0/00  Corporate Auto
# 4 36357.00                 68.00                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
car_insurance_df2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car              633.60
# 1            SUV              547.20
# ...

# %%
car_insurance_df3.head()
# Out:
#   Customer       State Gender             Education  Customer Lifetime Value  \
# 0  SA25987  Washington      M  High School or Below                  3479.14
# 1  TB86706     Arizona      M                Master                  2502.64
# 2  ZL73902      Nevada      F              Bachelor                  3265.16
# 3  KX23516  California      F  High School or Below                  4455.84
# 4  FN77294  California      M  High School or Below                  7704.96
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
import Henning_cleaning_functions as cf

# %%
column_replacements = {"st":"state"}
whole_replacements = {"Male":"M",("female", "Femal"):"F","AZ":"Arizona","Cali":"California","WA":"Washington",("Sports Car", "Luxury SUV", "Luxury Car"):"Luxury", "Bachelors":"Bachelor"}
substring_replacements = {'%': ''}
char_columns = ['number_of_open_complaints']
recast_columns = ["customer_lifetime_value","income","monthly_premium_auto","total_claim_amount","number_of_open_complaints"]
mean_columns = ["customer_lifetime_value"]
gender_columns = ['gender']
dupe_columns = ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'state', 'policy_type', 'gender']

# %%
cleaned_df1 = cf.clean_dataset(car_insurance_df1, column_replacements, whole_replacements, substring_replacements, char_columns, recast_columns, mean_columns, gender_columns, dupe_columns)

# %%
cleaned_df1.head(50)
# Out:
#    customer       state gender             education  customer_lifetime_value  \
# 0   RB50392  Washington      F                Master                   793690
# 1   QZ44356     Arizona      F              Bachelor                   697954
# 2   AI49188      Nevada      F              Bachelor                  1288743
# 3   WW63253  California      M              Bachelor                   764586
# 4   GA49547  Washington      M  High School or Below                   536308
# 5   OC83172      Oregon      F              Bachelor                   825630
# 6   XZ87318      Oregon      F               College                   538090
# 7   CF85061     Arizona      M                Master                   721610
# 8   DY87989      Oregon      M              Bachelor                  2412750
# 9   BQ94931      Oregon      F               College                   738818
# 10  SX51350  California      M               College                   473899
# ...

# %%
cleaned_df1.dtypes
# Out:
# customer                     object
# state                        object
# gender                       object
# education                    object
# customer_lifetime_value       Int64
# income                        Int64
# monthly_premium_auto          Int64
# number_of_open_complaints     Int64
# policy_type                  object
# vehicle_class                object
# total_claim_amount            Int64
# dtype: object

# %%
cleaned_df2 = cf.clean_dataset(car_insurance_df2, column_replacements, whole_replacements, substring_replacements, char_columns, recast_columns, mean_columns, gender_columns, dupe_columns)

# %%
cleaned_df3 = cf.clean_dataset(car_insurance_df3, column_replacements, whole_replacements, substring_replacements, char_columns, recast_columns, mean_columns, gender_columns, dupe_columns)

# %%
cleaned_df2.head(50)
# Out:
#    customer       state gender             education  customer_lifetime_value  \
# 0   GS98873     Arizona      F              Bachelor                   323912
# 1   CW49887  California      F                Master                   462680
# 2   MY31220  California      F               College                   899704
# 3   UH35128      Oregon      F               College                  2580706
# 4   WH52799     Arizona      F               College                   380812
# 5   WL99637     Arizona      M              Bachelor                   761414
# 6   UC84059  California      F                Master                   689846
# 7   HW62747      Oregon      M               College                   229838
# 8   BH11344      Oregon      F                Doctor                   280670
# 9   TX28465      Nevada      M               College                   520612
# 10  OK56965  California      F              Bachelor                  4570865
# ...

# %%
cleaned_df3.head(50)
# Out:
#    customer       state gender             education  customer_lifetime_value  \
# 0   SA25987  Washington      M  High School or Below                     3479
# 1   TB86706     Arizona      M                Master                     2503
# 2   ZL73902      Nevada      F              Bachelor                     3265
# 3   KX23516  California      F  High School or Below                     4456
# 4   FN77294  California      M  High School or Below                     7705
# 5   VI78454     Arizona      M               College                     2751
# 6   FP59138      Oregon      M                Master                    13024
# 7   XN62489      Oregon      M              Bachelor                     2539
# 8   GP66031  California      F               College                     2586
# 9   IX68587      Nevada      F                Master                     5097
# 10  HX17929  California      F  High School or Below                    10083
# ...

# %%
cleaned_df3.size
# Out:
# 75075

# %%
car_insurance_df3.size
# Out:
# 77770

# %%
#concatenate:
car_insurance_concat = pd.concat([cleaned_df1,cleaned_df2,cleaned_df3], axis = 0, ignore_index=True)
car_insurance_concat
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 8874  LA72316  California      M              Bachelor
# 8875  PK87824  California      F               College
# 8876  TD14365  California      M              Bachelor
# 8877  UP19263  California      M               College
# 8878  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      793690       0                  1000
# 1                      697954       0                    94
# 2                     1288743   48767                   108
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
ci_marketing = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")
ci_marketing.head(20)
# Out:
#     unnamed:_0 customer       state  customer_lifetime_value response  \
# 0            0  DK49336     Arizona                  4809.22       No
# 1            1  KX64629  California                  2228.53       No
# 2            2  LZ68649  Washington                 14947.92       No
# 3            3  XL78013      Oregon                 22332.44      Yes
# 4            4  QA50777      Oregon                  9025.07       No
# 5            5  HO81102  California                  4745.18       No
# 6            6  IW72280  California                  5035.04       No
# 7            7  IH64929  California                  4956.25       No
# 8            8  FM55990  California                  5989.77      Yes
# 9            9  QX31376      Oregon                 17114.33       No
# 10          10  HG93801     Arizona                  5154.76       No
# 11          11  GE63585  California                  2420.71       No
# ...

# %%
ci_marketing.isnull().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# ...

# %%
ci_marketing.duplicated().sum()
# Out:
# 0

# %%
ci_marketing.tail(20)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 10890       10890  VQ78876      Oregon                  4660.40       No
# 10891       10891  UV43859      Oregon                  8840.19       No
# 10892       10892  BC87551  California                 32306.29       No
# 10893       10893  CG69038  Washington                  4817.99       No
# 10894       10894  EX63393  California                  6314.49       No
# 10895       10895  EG40670  California                  6232.69       No
# 10896       10896  HT87217      Oregon                 19776.57       No
# 10897       10897  MM70762     Arizona                  9075.77      Yes
# 10898       10898  SO95845  California                  5807.66       No
# 10899       10899  WU60905  California                  8610.67       No
# 10900       10900  VN73653      Oregon                  6423.74       No
# 10901       10901  RY92254  Washington                  4547.89       No
# ...

# %%
ci_marketing.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
ci_clean = ci_marketing.drop(columns="unnamed:_0")

# %%
ci_clean.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
ci_clean.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                  4809.22       No     Basic   College
# 1  KX64629  California                  2228.53       No     Basic   College
# 2  LZ68649  Washington                 14947.92       No     Basic  Bachelor
# 3  XL78013      Oregon                 22332.44      Yes  Extended   College
# 4  QA50777      Oregon                  9025.07       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-18         Employed      M   48029      Suburban
# 1        2011-01-18       Unemployed      F       0      Suburban
# 2        2011-02-10         Employed      M   22139      Suburban
# 3        2011-01-11         Employed      M   49078      Suburban
# 4        2011-01-17    Medical Leave      F   23675      Suburban
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %%
ci_clean["total_revenue"] = ci_clean["monthly_premium_auto"]*ci_clean["months_since_policy_inception"]

# %%
ci_clean
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 4      QA50777      Oregon                  9025.07       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada                 15563.37       No   Premium
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
# 10909  IV32877  California                  6857.52       No     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
pivot_rev = ci_clean.pivot_table(
    values='total_revenue',
    index='sales_channel',
    aggfunc='sum'
)

# %%
pivot_rev = pivot_table.round(2)
pivot_rev
# Out:
#                total_revenue
# sales_channel
# Agent               18534081
# Branch              13711669
# Call Center          9376066
# Web                  7475544

# %%
#from the data it is clear that the Agent channel brought in the most revenue

# %%
pivot_clv = ci_clean.pivot_table(
    values='customer_lifetime_value',
    index='gender',
    columns='education',
    aggfunc='mean'
)

# %%
new_order_clv = ["High School or Below","College","Bachelor","Master","Doctor"]
pivot_clv = pivot_clv[new_order_clv]

# %%
pivot_clv
# Out:
# education  High School or Below  College  Bachelor  Master  Doctor
# gender
# F                       8675.22  7748.82   7874.27 8157.05 7328.51
# M                       8149.69  8052.46   7703.60 8168.83 7415.33

# %%
pivot_clv2 = ci_clean.pivot_table(
    values='customer_lifetime_value',
    index='education',
    columns='gender',
    aggfunc='mean'
)

# %%
ci_clean["customer_lifetime_value"].describe()
# Out:
# count   10910.00
# mean     8018.24
# std      6885.08
# min      1898.01
# 25%      4014.45
# 50%      5771.15
# 75%      8992.78
# max     83325.38
# Name: customer_lifetime_value, dtype: float64

# %%
#surprisingly, people with a high-school-or-below education have the highest calculated customer lifetime value, women even moreso than men.
#and doctors have the lowest. The difference between genders is smaller with a higher education level.

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
